# %%
#Install Variables ----------------------------------------->>>>>>>>>>
# !pip install anthropic python-dotenv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 15.8 MB/s eta 0:00:00
# ...

# %%
#Load env variable -------------------------------------------->>>>>>>>>

ANTHROPIC_API_KEY = ""

# %%
# Create an API client

from anthropic import Anthropic
client = Anthropic(api_key= ANTHROPIC_API_KEY)
model = "sonnet-4-0"

# %%
# Make a request ------------------------------------------->>>>>>>>>>

def add_user_messages(message, text):
    user_messages = {"role": "user", "content": text}
    message.append(user_messages)

def add_assistant_messages(message, text):
    assistant_messages = {"role": "assistant", "content": text}
    message.append(assistant_messages)


def chat(messages):
    response = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages
    )
    return response.content[0].text

# %%
#Make a starting list of messages
messages = []

#Add in the initial user question of "Define quantum computing in one sentence"

add_user_messages(messages, "Define quantum computing in one sentence")

#Pass the list of messages into 'chat' to get an answer

answer = chat(messages)
print(answer)

#Take the answer and add it as an assistant message into our list
 add_assistant_messages(messages , answer)


#Add in the user's follow-up question

add_user_messages(messages, "Write another message")

#Call chat again with the list of pssages to get a final answer

answer = chat(messages)
print(answer)
# Out:
#   File "/tmp/ipykernel_1422/1110335934.py", line 14
#     add_assistant_messages(messages , answer)
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# **<-------------Anthropic ChatBot Exercise -------------->>>>**

# %%
messages = []

while True:
  user_input = input("> ")
  print(">", user_input)
  add_user_messages(messages , user_input)
  answer = chat(messages)
  print(">", answer)
  add_assistant_messages(messages , answer)
  print("----")
  print(answer)
  print("----")
# Out:
# > 1 + 2
# > 1 + 2
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# /tmp/ipykernel_1422/4026727435.py in <cell line: 0>()
#       5   print(">", user_input)
#       6   add_user_messages(messages , user_input)
# ----> 7   answer = chat(messages)
#       8   print(">", answer)
#       9   add_assistant_messages(messages , answer)
#
# /tmp/ipykernel_1422/2232969345.py in chat(messages)
#      11
#      12 def chat(messages):
# ---> 13     response = client.messages.create(
#      14         model=model,
#      15         max_tokens=1000,
#
# /usr/local/lib/python3.13/dist-packages/anthropic/_utils/_utils.py in wrapper(*args, **kwargs)
#     292                         msg = f"Missing required argument: {quote(missing[0])}"
#     293                 raise TypeError(msg)
# --> 294             return func(*args, **kwargs)
#     295
#     296         return wrapper  # type: ignore
#
# ...
